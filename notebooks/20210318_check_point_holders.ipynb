# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

import os.path

# %%
base_path = "/Users/regevschweiger/git/matrix_shuffle/datasets/ela_chr19/"
run_name = "run_20210318_testme_srf"

orig_points_filename = os.path.join(base_path, run_name, "output.0")
points_filename = os.path.join(base_path, run_name, "output.100000000")

# %%
orig_points = pd.read_csv(orig_points_filename, sep="\s+", header=None)

# %%
plt.figure(figsize=(10,8))
plt.plot(
    orig_points[0].values,
    orig_points[1].values,
    '.',
    ms=0.3,
    alpha=0.05,
)

# %%
points = pd.read_csv(points_filename, sep="\s+", header=None)

# %%
plt.figure(figsize=(10,8))
plt.plot(
    points[0].values,
    points[1].values,
    '.',
    ms=0.3,
    alpha=1,
)

# %%
# Point of reference
